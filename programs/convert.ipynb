# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from tf.app import use

from tfFromTxt import Converter

# %%
PALI = "pali"
LATIN = "latin"

X = Converter()
# Out:
# READING pali
# Change stanza 143a to 143
# Append stanza 143b to previous stanza
# pali : 1609 lines
# READING latin
# latin:  475 lines

# %%
X.showText(PALI, 533, 539, logical=False)
# Out:
# TEXT OF pali
#  524: 143 hirīnisedho puriso koci lokasmi vijjati
#  525: yo nindaṃ appabodhati asso bhadro kasām iva.
#  526: asso yathā bhadro kasāniviṭṭho
#  527: ātāpino saṃvegino bhavātha.
#  528:
#  529: 144 saddhāya sīlena ca vīriyena ca
#  530: samādhinā dhammavinicchayena ca

# %%
X.showText(PALI, 781, 790, logical=False)
# Out:
# TEXT OF pali
#  772: dukkho bālehi saṃvāso amittenêva sabbadā,
#  773: dhīro ca sukhasaṃvāso ñātīnaṃ va samāgamo.
#  774:
#  775: tasmā hi:
#  776:
#  777: 208 dhīrañ ca paññañ ca bahussutañ ca
#  778: dhorayhasīlaṃ vatavantam āriyaṃ
#  779: taṃ tādisaṃ sappurisaṃ sumedhaṃ
#  780: bhajetha nakkhattapathaṃ va candimā.
#  781:

# %%
X.showText(LATIN, 343, 350, logical=False)
# Out:
# TEXT OF latin
#  326: 286 “Hic per tempus pluvium habitabo, hic frigido et fervido (tempore)”, sic
#       stultus secum volvit, interitum (vitae) non animadvertit.
#  327: 287 Illum de filiis et pecudibus sollicitum, constrictae mentis virum, sopitum
#       vicum torrens velut, mors prehendens proficiscitur.
#  328: 288 Non sunt filii saluti, non pater neque propinqui; quem mors adiit, ei non
#       est penes cognatos salus.
#  329: 289 Hac rei vi perspecta sapiens virtute temperatus viam ad Nibbānum ducentem
#       cito purget.
#  330:
#  331: XXI
#  332: 290 Exigui gaudii relictione si videt amplum gaudium, relinquat exiguum gaudium
#       sapiens, amplum gaudium spectans.
#  333: 291 Aliis dolorem imponendo qui suum ipsius gaudium exoptat, iracundiae vinculo
#       vinctus, iracundia ille non liberatur.

# %%
X.tokenize()
# Out:
# TOKENIZING pali
#   76: Vagga tail after vagga  1 and stanza  20: Yamakavaggo paṭhamo
#  118: Vagga tail after vagga  2 and stanza  32: Appamādavaggo dutiyo
#  159: Vagga tail after vagga  3 and stanza  43: Cittavaggo tatiyo
#  222: Vagga tail after vagga  4 and stanza  59: Pupphavaggo catuttho
#  277: Vagga tail after vagga  5 and stanza  75: Bālavagga pañcamo
#  333: Vagga tail after vagga  6 and stanza  89: Paṇḍitavaggo chaṭṭho
#  374: Vagga tail after vagga  7 and stanza  99: Arahantavaggo sattamo
#  430: Vagga tail after vagga  8 and stanza 115: Sahassavaggo aṭṭhamo
#  483: Vagga tail after vagga  9 and stanza 128: Pāpavaggo navamo
#  548: Vagga tail after vagga 10 and stanza 145: Daṇḍavaggo dasamo
#  588: Vagga tail after vagga 11 and stanza 156: Jarāvaggo ekādasamo
#  626: Vagga tail after vagga 12 and stanza 166: Attavaggo dvādasamo
#  668: Vagga tail after vagga 13 and stanza 178: Lokavaggo terasamo
#  742: Vagga tail after vagga 14 and stanza 196: Buddhavaggo cuddasamo
# ...

# %%
X.showTokens(stanza=1)
# Out:
# TOKENS OF pali
# ±ln  11:v 1:s  1: 1, 1 │   │    │manopubbaṅgamā      │
# ±ln  11:v 1:s  1: 1, 1 │   │    │dhammā              │
# ±ln  11:v 1:s  1: 1, 1 │   │    │manoseṭṭhā          │
# ±ln  11:v 1:s  1: 1, 1 │   │    │manomayā            │,
# ±ln  12:v 1:s  1: 1, 2 │   │    │manasā              │
# ±ln  12:v 1:s  1: 1, 2 │   │    │ce                  │
# ±ln  12:v 1:s  1: 1, 2 │   │    │paduṭṭhena          │
# ±ln  12:v 1:s  1: 1, 2 │   │    │bhāsatī             │
# ±ln  12:v 1:s  1: 1, 2 │   │    │vā                  │
# ±ln  12:v 1:s  1: 1, 2 │   │    │karoti              │
# ±ln  12:v 1:s  1: 1, 2 │   │    │vā                  │
# ±ln  13:v 1:s  1: 1, 2 │   │    │tato                │
# ±ln  13:v 1:s  1: 1, 2 │   │    │naṃ                 │
# ±ln  13:v 1:s  1: 1, 2 │   │    │dukkham             │
# ±ln  13:v 1:s  1: 1, 2 │   │    │anveti              │
# ±ln  13:v 1:s  1: 1, 2 │   │    │cakkaṃ              │
# ±ln  13:v 1:s  1: 1, 2 │   │    │va                  │
# ...

# %%
X.showTokens(stanza=286)
# Out:
# TOKENS OF pali
# ±ln1074:v20:s286:14,28 │   │    │idha                │
# ±ln1074:v20:s286:14,28 │   │    │vassaṃ              │
# ±ln1074:v20:s286:14,28 │   │    │vasissāmi           │
# ±ln1074:v20:s286:14,28 │   │    │idha                │
# ±ln1074:v20:s286:14,28 │   │    │hemantagimhisu      │
# ±ln1075:v20:s286:14,28 │   │    │iti                 │
# ±ln1075:v20:s286:14,28 │   │    │bālo                │
# ±ln1075:v20:s286:14,28 │   │    │vicinteti           │
# ±ln1075:v20:s286:14,28 │   │    │antarāyaṃ           │
# ±ln1075:v20:s286:14,28 │   │    │na                  │
# ±ln1075:v20:s286:14,28 │   │    │bujjhati            │.
# TOKENS OF latin
# ±ln 343:v20:s286:17,55 │"  │   "│Hic                 │
# ±ln 343:v20:s286:17,55 │"  │    │per                 │
# ±ln 343:v20:s286:17,55 │"  │    │tempus              │
# ±ln 343:v20:s286:17,55 │"  │    │pluvium             │
# ±ln 343:v20:s286:17,55 │"  │    │habitabo            │,
# ...

# %%
X.chunkify()
# Out:
# CHUNKIFYING pali
# CHUNKIFYING latin

# %%
X.showChunks(vagga=19)
# Out:
# LETTERS OF pali
# Vagga 19
# 	1256
# 		sentence 0
# 			clause 0
# 				│   │    │Dhammaṭṭhavagga     │
# 	256
# 		sentence 1
# 			clause 1
# 				│   │    │na                  │
# 				│   │    │tena                │
# 				│   │    │hoti                │
# 				│   │    │dhammaṭṭho          │
# 				│   │    │yen'                │
# 				│   │    │atthaṃ              │
# 				│   │    │sahasā              │
# 				│   │    │naye                │,
# 			clause 2
# 				│   │    │yo                  │
# 				│   │    │ca                  │
# 				│   │    │atthaṃ              │
# 				│   │    │anatthañ            │
# 				│   │    │ca                  │
# 				│   │    │ubho                │
# 				│   │    │niccheyya           │
# 				│   │    │paṇḍito             │
# 	257
# 		sentence 1
# 			clause 2
# 				│   │    │asāhasena           │
# 				│   │    │dhammena            │
# 				│   │    │samena              │
# 				│   │    │nayatī              │
# 				│   │    │pare                │
# ...

# %%
X.showChunks(vagga=1)
# Out:
# LETTERS OF pali
# Vagga 1
# 	1001
# 		sentence 0
# 			clause 0
# 				│   │    │Yamakavagga         │
# 	1
# 		sentence 1
# 			clause 1
# 				│   │    │manopubbaṅgamā      │
# 				│   │    │dhammā              │
# 				│   │    │manoseṭṭhā          │
# 				│   │    │manomayā            │,
# 			clause 2
# 				│   │    │manasā              │
# 				│   │    │ce                  │
# 				│   │    │paduṭṭhena          │
# 				│   │    │bhāsatī             │
# 				│   │    │vā                  │
# 				│   │    │karoti              │
# 				│   │    │vā                  │
# 				│   │    │tato                │
# 				│   │    │naṃ                 │
# 				│   │    │dukkham             │
# 				│   │    │anveti              │
# 				│   │    │cakkaṃ              │
# 				│   │    │va                  │
# 				│   │    │vahato              │
# 				│   │    │padaṃ               │.
# 	2
# 		sentence 2
# 			clause 3
# 				│   │    │manopubbaṅgamā      │
# 				│   │    │dhammā              │
# ...

# %%
X.showChunks(stanza=2)
# Out:
# LETTERS OF pali
# Vagga 1
# 	2
# 		sentence 2
# 			clause 3
# 				│   │    │manopubbaṅgamā      │
# 				│   │    │dhammā              │
# 				│   │    │manoseṭṭhā          │
# 				│   │    │manomayā            │,
# 			clause 4
# 				│   │    │manasā              │
# 				│   │    │ce                  │
# 				│   │    │pasannena           │
# 				│   │    │bhāsatī             │
# 				│   │    │vā                  │
# 				│   │    │karoti              │
# 				│   │    │vā                  │
# 				│   │    │tato                │
# 				│   │    │naṃ                 │
# 				│   │    │sukham              │
# 				│   │    │anveti              │
# 				│   │    │chāyā               │
# 				│   │    │va                  │
# 				│   │    │anapāyinī           │.
# LETTERS OF latin
# Vagga 1
# 	2
# 		sentence 2
# 			clause 7
# 				│   │    │Naturae             │
# 				│   │    │a                   │
# 				│   │    │mente               │
# 				│   │    │etc                 │.;
# 		sentence 3
# ...

# %%
X.showLetters()
# Out:
# LETTERS OF pali
# │a│ :    7483 x
# │ │ :    5781 x
# │t│ :    2556 x
# │i│ :    2042 x
# │h│ :    1982 x
# │ā│ :    1982 x
# │s│ :    1965 x
# │n│ :    1655 x
# │ṃ│ :    1379 x
# │m│ :    1279 x
# │o│ :    1233 x
# │p│ :    1223 x
# │d│ :    1033 x
# │e│ :    1022 x
# │u│ :    1002 x
# │k│ :     999 x
# │v│ :     985 x
# │y│ :     848 x
# │r│ :     834 x
# │c│ :     827 x
# │b│ :     677 x
# │g│ :     511 x
# │j│ :     457 x
# │.│ :     429 x
# │ñ│ :     379 x
# │ī│ :     309 x
# │l│ :     266 x
# │ṇ│ :     233 x
# │,│ :     219 x
# │1│ :     208 x
# │2│ :     198 x
# │ṭ│ :     198 x
# │3│ :     188 x
# │'│ :     147 x
# │ū│ :     118 x
# │4│ :     110 x
# │5│ :      85 x
# │6│ :      85 x
# │0│ :      84 x
# │7│ :      84 x
# │8│ :      84 x
# │9│ :      84 x
# │ḍ│ :      83 x
# │â│ :      57 x
# │-│ :      49 x
# │"│ :      26 x
# │B│ :      25 x
# │ṅ│ :      24 x
# │M│ :      23 x
# │ḷ│ :      17 x
# │P│ :      11 x
# │A│ :      10 x
# │:│ :       8 x
# │[│ :       8 x
# ...

# %%
X.showAffixes()
# Out:
# AFFIXES OF pali
# 〈 │  :    4883 x
# 〈. │ :     402 x
# 〈, │ :     214 x
# 〈  - │ :      25 x
# 〈: │ :       8 x
# 〈] │ :       8 x
# 〈" │ :       7 x
# 〈", │ :       5 x
# 〈; │ :       2 x
# 〈? │ :       2 x
# 〈". │ :       1 x
# 〈,  - │ :       1 x
# │〉   :    5511 x
# │"〉  :      13 x
# │[〉  :       8 x
# AFFIXES OF latin
# 〈 │  :    5487 x
# 〈, │ :     992 x
# 〈. │ :     369 x
# 〈) │ :     286 x
# 〈; │ :     112 x
# 〈), │ :      54 x
# 〈). │ :      31 x
# 〈: │ :      17 x
# 〈? │ :      13 x
# 〈,  - │ :       8 x
# 〈”, │ :       7 x
# 〈); │ :       6 x
# 〈  - │ :       4 x
# 〈): │ :       4 x
# 〈”; │ :       3 x
# 〈)”, │ :       2 x
# 〈│   :       1 x
# 〈! │ :       1 x
# 〈)│  :       1 x
# 〈)”; │ :       1 x
# 〈.; │ :       1 x
# 〈.”; │ :       1 x
# 〈” │ :       1 x
# │〉   :    6990 x
# │(〉  :     385 x
# │“〉  :      15 x

# %%
X.makeTf()
# Out:
# This is Text-Fabric 9.1.11
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 15 features found and 0 ignored
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    vagga, stanza
#    |   SECTION   FEATURES: n, n
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-latin-full      latin, latinpost, latinpre
#    |      |   text-orig-full       latin, latinpost, latinpre, pali, palipost, palipre
#    |      |   text-pali-full       pali, palipost, palipre
#    |     0.00s OK
#    |     0.00s Following director...
#    |     0.08s "edge" actions: 0
#    |     0.08s "feature" actions: 29516
#    |     0.08s "node" actions: 3672
#    |     0.08s "resume" actions: 1744
#    |     0.08s "slot" actions: 12922
#    |     0.08s "terminate" actions: 5520
#    |       2299 x "clause" node
# ...

# %%
X.loadTf()
# Out:
# This is Text-Fabric 9.1.11
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 15 features found and 0 ignored
#    |     0.03s T otype                from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.14s T oslots               from ~/github/etcbc/dhammapada/tf/0.1
#   0.17s Dataset without structure sections in otext:no structure functions in the T-API
#    |     0.02s T palipre              from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.03s T palipost             from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.03s T latinpre             from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.03s T pali                 from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.02s T n                    from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.04s T latinpost            from ~/github/etcbc/dhammapada/tf/0.1
#    |     0.04s T latin                from ~/github/etcbc/dhammapada/tf/0.1
# ...

# %%
A = use("dhammapada:clone", checkout="clone", hoist=globals())
# Out:
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-dhammapada/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/dhammapada/tf/0.1</span>
# This is Text-Fabric 9.1.11
# Api reference : https://annotation.github.io/text-fabric/tf/cheatsheet.html
#
# 15 features found and 0 ignored
# ...

# %%
clauses = F.otype.s("clause")
clausesPali = [c for c in clauses if not F.trans.v(c)]
clausesLatin = [c for c in clauses if F.trans.v(c)]
print(f"""
{len(clauses):>4} clauses
{len(clausesPali):>4} clauses in Pali
{len(clausesLatin):>4} clauses in Latin
""")
# Out:
# 2299 clauses
#  686 clauses in Pali
# 1613 clauses in Latin

# %%
for c in clauses[0:20]:
    lang = LATIN if F.trans.v(c) else PALI
    print(f"{lang:<5} {T.text(c)}")
# Out:
# pali  Yamakavagga
# pali  manopubbaṅgamā  dhammā  manoseṭṭhā  manomayā,
# pali  manasā  ce  paduṭṭhena  bhāsatī  vā  karoti  vā  tato  naṃ  dukkham  anveti  cakkaṃ  va  vahato  padaṃ.
# latin Naturae  a  mente  principium  ducunt,
# latin mens  est  potior  pars  earum,
# latin e  mente  constant;
# latin si  (quis)  mente  inquinata  aut  loquitur  aut  agit,
# latin tum  eum  sequitur  dolor,
# latin ut  rota  (bovis)  vehentis  pedem.
# pali  manopubbaṅgamā  dhammā  manoseṭṭhā  manomayā,
# pali  manasā  ce  pasannena  bhāsatī  vā  karoti  vā  tato  naṃ  sukham  anveti  chāyā  va  anapāyinī.
# latin Naturae  a  mente  etc.;
# latin si  (quis)  mente  serena  aut  loquitur  aut  agit,
# latin tum  eum  sequitur  gaudium  ut  umbra  non  decedens.
# pali  "akkocchi  maṃ  avadhi  maṃ  ajini  maṃ  ahāsi  me",
# pali  ye  taṃ  upanayihanti  veraṃ  tesaṃ  na  sammati.
# latin "Conviciis  me  obruit,
# latin verberavit  me,
# latin vicit  me,
# latin spoliavit  me”;

# %%
for c in F.otype.s("stanza")[0:2]:
    A.plain(c, fmt="layout-orig-full")
    A.plain(c, fmt="layout-pali-full")
    A.plain(c, fmt="layout-latin-full")
    A.pretty(c, fmt="layout-orig-full")
# Out:
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="http://www.buddhanet.net/e-learning/buddhism/dp01.htm/dp=01.htm" title="Show English translation on Buddhanet" sec="1 1001">1 1001</a></span></span>  <span class="txtu"><span class="extrastanza1">Yamakavagga </span></span></div>
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="http://www.buddhanet.net/e-learning/buddhism/dp01.htm/dp=01.htm" title="Show English translation on Buddhanet" sec="1 1001">1 1001</a></span></span>  <span class="txtn"><span class="extrastanza1">Yamakavagga </span></span></div>
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="http://www.buddhanet.net/e-learning/buddhism/dp01.htm/dp=01.htm" title="Show English translation on Buddhanet" sec="1 1001">1 1001</a></span></span>  <span class="txtn"><span class="extrastanza1"></span></span></div>
# ...
