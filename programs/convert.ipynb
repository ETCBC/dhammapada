# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from tfFromTxt import Converter

# %%
PALI = "pali"
LATIN = "latin"

C = Converter()
# Out:
# pali : 1610 lines
# latin:  473 lines

# %%
C.show(LATIN, 1, 10)
# Out:
#   18: I
#   19: 1 Naturae a mente principium ducunt, mens est potior pars earum, e mente
#       constant; si (quis) mente inquinata aut loquitur aut agit, tum eum
#       sequitur dolor, ut rota (bovis) vehentis pedem.
#   20: 2 Naturae a mente etc.; si (quis) mente serena aut loquitur aut agit, tum eum
#       sequitur gaudium ut umbra non decedens.
#   21: 3 “Conviciis me obruit, verberavit me, vicit me, spoliavit me”; qui isto (animo)
#       sese induunt, iracundia eorum non sedatur.
#   22: 4 “Conviciis etc.”; qui isto (animo) sese non induunt, iracundia in iis sedatur.
#   23: 5 Non enim iracundia iracundiae sedantur hic unquam, placabilitate vero
#       sedantur; haec lex aeterna (est).
#   24: 6 Alieni non intelligunt: nos hic moriemur; qui vero hoc comprehendunt, tum
#       (eorum) sedantur iurgia.
#   25: 7 Iucunda spectantem viventem, sensus non coercentem et in cibo modi nescium,
#       socordem, viribus destitutum, eum certe superat Māras, ventus arborem
# ...

# %%
C.show(PALI, 1, 10)
# Out:
#   10: 1. Yamakavagga
#   11: 1 manopubbaṅgamā dhammā manoseṭṭhā manomayā,
#   12: manasā ce paduṭṭhena bhāsatī vā karoti vā
#   13: tato naṃ dukkham anveti cakkaṃ va vahato padaṃ.
#   14:
#   15: 2 manopubbaṅgamā dhammā manoseṭṭhā manomayā,
#   16: manasā ce pasannena bhāsatī vā karoti vā
#   17: tato naṃ sukham anveti chāyā va anapāyinī.
#   18:
#   19: 3 "akkocchi maṃ avadhi maṃ ajini maṃ ahāsi me",

# %%
C.chunkPali()
# Out:
# 1619: 26 vaggas
# 1619: 423 stanzas

# %%
C.showLetters(PALI)
# Out:
# │a│ :    7484 x
# │ │ :    5781 x
# │t│ :    2556 x
# │i│ :    2042 x
# │h│ :    1982 x
# │ā│ :    1982 x
# │s│ :    1965 x
# │n│ :    1655 x
# │ṃ│ :    1379 x
# │m│ :    1279 x
# │o│ :    1233 x
# │p│ :    1223 x
# │d│ :    1033 x
# │e│ :    1022 x
# │u│ :    1002 x
# │k│ :     999 x
# │v│ :     985 x
# │y│ :     848 x
# │r│ :     834 x
# │c│ :     827 x
# │b│ :     677 x
# │g│ :     511 x
# │j│ :     457 x
# │.│ :     426 x
# │ñ│ :     379 x
# │ī│ :     309 x
# │l│ :     266 x
# │ṇ│ :     233 x
# │,│ :     219 x
# │1│ :     208 x
# │2│ :     198 x
# │ṭ│ :     198 x
# │3│ :     188 x
# │'│ :     147 x
# │ū│ :     118 x
# │4│ :     110 x
# │5│ :      85 x
# │6│ :      85 x
# │0│ :      84 x
# │7│ :      84 x
# │8│ :      84 x
# │9│ :      84 x
# │ḍ│ :      83 x
# │â│ :      57 x
# │-│ :      49 x
# │"│ :      26 x
# │B│ :      25 x
# │ṅ│ :      24 x
# │M│ :      23 x
# │ḷ│ :      17 x
# │P│ :      11 x
# │A│ :       9 x
# │:│ :       8 x
# │[│ :       8 x
# │]│ :       8 x
# ...

# %%
C.showAffixes(PALI)
# Out:
# 〈│   :    4912 x
# 〈.│  :     399 x
# 〈,│  :     214 x
# 〈:│  :       8 x
# 〈]│  :       8 x
# 〈"│  :       7 x
# 〈",│ :       5 x
# 〈;│  :       2 x
# 〈?│  :       2 x
# 〈".│ :       1 x
# │〉   :    5537 x
# │"〉  :      13 x
# │[〉  :       8 x

# %%
C.showChunks(PALI)
# Out:
# ln10:v1:s0:1,1=│Yamakavagga│
# ln11:v1:s1:1,1=│manopubbaṅgamā│
# ln11:v1:s1:1,1=│dhammā│
# ln11:v1:s1:1,1=│manoseṭṭhā│
# ln11:v1:s1:1,1=│manomayā│,
# ln12:v1:s1:1,2=│manasā│
# ln12:v1:s1:1,2=│ce│
# ln12:v1:s1:1,2=│paduṭṭhena│
# ln12:v1:s1:1,2=│bhāsatī│
# ln12:v1:s1:1,2=│vā│
# ln12:v1:s1:1,2=│karoti│
# ln12:v1:s1:1,2=│vā│
# ln13:v1:s1:1,2=│tato│
# ln13:v1:s1:1,2=│naṃ│
# ln13:v1:s1:1,2=│dukkham│
# ln13:v1:s1:1,2=│anveti│
# ln13:v1:s1:1,2=│cakkaṃ│
# ln13:v1:s1:1,2=│va│
# ln13:v1:s1:1,2=│vahato│
# ln13:v1:s1:1,2=│padaṃ│.
# ln15:v1:s2:2,3=│manopubbaṅgamā│
# ln15:v1:s2:2,3=│dhammā│
# ln15:v1:s2:2,3=│manoseṭṭhā│
# ln15:v1:s2:2,3=│manomayā│,
# ln16:v1:s2:2,4=│manasā│
# ln16:v1:s2:2,4=│ce│
# ln16:v1:s2:2,4=│pasannena│
# ln16:v1:s2:2,4=│bhāsatī│
# ln16:v1:s2:2,4=│vā│
# ln16:v1:s2:2,4=│karoti│
# ln16:v1:s2:2,4=│vā│
# ln17:v1:s2:2,4=│tato│
# ln17:v1:s2:2,4=│naṃ│
# ln17:v1:s2:2,4=│sukham│
# ln17:v1:s2:2,4=│anveti│
# ln17:v1:s2:2,4=│chāyā│
# ln17:v1:s2:2,4=│va│
# ln17:v1:s2:2,4=│anapāyinī│.
# ...
